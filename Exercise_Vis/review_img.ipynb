# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as im

# %%
pict = im.imread('matlab01.jpg')
pict
# Out:
# array([[[ 4,  3,  1],
#         [ 5,  1,  0],
#         [ 4,  0,  0],
#         ...,
#         [25,  0,  0],
#         [25,  0,  0],
#         [28,  2,  3]],
#
#        [[ 4,  3,  1],
#         [ 5,  1,  0],
#         [ 4,  0,  0],
#         ...,
#         [25,  0,  0],
#         [25,  0,  0],
#         [30,  4,  5]],
#
#        [[ 4,  3,  1],
#         [ 5,  1,  0],
#         [ 4,  0,  0],
#         ...,
#         [25,  0,  0],
#         [27,  2,  0],
#         [34,  8,  7]],
#
#        ...,
#
#        [[ 6,  2,  0],
#         [ 6,  2,  0],
#         [ 6,  2,  0],
#         ...,
#         [10,  7,  2],
#         [10,  7,  2],
#         [10,  7,  2]],
#
#        [[ 6,  2,  0],
#         [ 6,  2,  0],
#         [ 6,  2,  0],
#         ...,
#         [ 9,  6,  1],
#         [ 9,  6,  1],
#         [ 9,  6,  1]],
#
#        [[ 6,  2,  0],
#         [ 6,  2,  0],
#         [ 6,  2,  0],
#         ...,
#         [ 8,  5,  0],
#         [ 8,  5,  0],
#         [ 8,  5,  0]]], dtype=uint8)

# %%
plt.imshow(pict)
