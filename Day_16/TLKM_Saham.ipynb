# %%
import pandas as pd

# %%
dfTLKM = pd.read_csv('TLKM.JK.csv',
                    parse_dates = ['Date'],
#                     index_col = 'Date'
                    )
dfTLKM = dfTLKM.set_index('Date')

# %%
# dfTLKM['Date'] = dfTLKM['Date'].astype('datetime64')
dfTLKM.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
dfTLKM['2019-08-01':'2019-08-01']
# Out:
#               Open    High     Low   Close  Adj Close    Volume
# Date
# 2019-08-01  4300.0  4300.0  4260.0  4280.0     4280.0  94856600

# %%
dfTLKM['2019-08']['Close'].max()
# Out:
# 4470.0

# %%
dfTLKM[dfTLKM['Close']==dfTLKM['2019-08']['Close'].max()]
# Out:
#               Open    High     Low   Close  Adj Close     Volume
# Date
# 2019-08-20  4350.0  4470.0  4340.0  4470.0     4470.0  143171600

# %%
dfTLKM['2019-09':'2019-10']['Close'].resample('W').mean()
# '''
# 'M' : month end
# 'W' : weekend
# 'Q' : quarter
# 'Y' : yearly
# '''
# Out:
# Date
# 2019-09-08    4316.0
# 2019-09-15    4224.0
# 2019-09-22    4248.0
# 2019-09-29    4270.0
# 2019-10-06    4230.0
# 2019-10-13    4120.0
# 2019-10-20    4178.0
# 2019-10-27    4264.0
# 2019-11-03    4242.5
# Freq: W-SUN, Name: Close, dtype: float64

# %%
import numpy as np
dfTLKM = dfTLKM.sort_index()
dfTLKM = dfTLKM.resample('D').sum()
dfTLKM.iloc[:,0:5] = dfTLKM.iloc[:,0:5].replace(0, np.NaN)
dfTLKM
# Out:
#               Open    High     Low   Close  Adj Close     Volume
# Date
# 2019-06-05  3900.0  3900.0  3900.0  3900.0     3900.0          0
# 2019-06-06  3900.0  3900.0  3900.0  3900.0     3900.0          0
# 2019-06-07  3900.0  3900.0  3900.0  3900.0     3900.0          0
# 2019-06-08     NaN     NaN     NaN     NaN        NaN          0
# 2019-06-09     NaN     NaN     NaN     NaN        NaN          0
# ...            ...     ...     ...     ...        ...        ...
# 2019-12-05  3990.0  4080.0  3990.0  4060.0     4060.0  118494800
# 2019-12-06  4040.0  4100.0  4020.0  4100.0     4100.0   50682100
# 2019-12-07     NaN     NaN     NaN     NaN        NaN          0
# 2019-12-08     NaN     NaN     NaN     NaN        NaN          0
# 2019-12-09  4080.0  4090.0  4050.0  4080.0     4080.0   24848200
#
# [188 rows x 6 columns]

# %%
dfTLKM = dfTLKM.fillna(method='ffill')
dfTLKM
# Out:
#               Open    High     Low   Close  Adj Close     Volume
# Date
# 2019-06-05  3900.0  3900.0  3900.0  3900.0     3900.0          0
# 2019-06-06  3900.0  3900.0  3900.0  3900.0     3900.0          0
# 2019-06-07  3900.0  3900.0  3900.0  3900.0     3900.0          0
# 2019-06-08  3900.0  3900.0  3900.0  3900.0     3900.0          0
# 2019-06-09  3900.0  3900.0  3900.0  3900.0     3900.0          0
# ...            ...     ...     ...     ...        ...        ...
# 2019-12-05  3990.0  4080.0  3990.0  4060.0     4060.0  118494800
# 2019-12-06  4040.0  4100.0  4020.0  4100.0     4100.0   50682100
# 2019-12-07  4040.0  4100.0  4020.0  4100.0     4100.0          0
# 2019-12-08  4040.0  4100.0  4020.0  4100.0     4100.0          0
# 2019-12-09  4080.0  4090.0  4050.0  4080.0     4080.0   24848200
#
# [188 rows x 6 columns]

# %%
dfTLKM['2019-05-01':'2019-07-10']
# Out:
#               Open    High     Low   Close  Adj Close     Volume
# Date
# 2019-06-05  3900.0  3900.0  3900.0  3900.0     3900.0          0
# 2019-06-06  3900.0  3900.0  3900.0  3900.0     3900.0          0
# 2019-06-07  3900.0  3900.0  3900.0  3900.0     3900.0          0
# 2019-06-08  3900.0  3900.0  3900.0  3900.0     3900.0          0
# 2019-06-09  3900.0  3900.0  3900.0  3900.0     3900.0          0
# 2019-06-10  4000.0  4060.0  3970.0  4040.0     4040.0  222522800
# 2019-06-11  4010.0  4060.0  4000.0  4020.0     4020.0   88861700
# 2019-06-12  3880.0  3950.0  3840.0  3940.0     3940.0  134724400
# 2019-06-13  3940.0  3990.0  3900.0  3990.0     3990.0  115734700
# 2019-06-14  4020.0  4050.0  3970.0  3990.0     3990.0   92466800
# 2019-06-15  4020.0  4050.0  3970.0  3990.0     3990.0          0
# 2019-06-16  4020.0  4050.0  3970.0  3990.0     3990.0          0
# 2019-06-17  3950.0  3970.0  3900.0  3900.0     3900.0   60851700
# ...
